# %% [markdown]
# # Applied Data Science Capstone Project

# %% [markdown]
# ### Importing the required Libraries

# %% [markdown]
# Importing the required libraries for initial data manipulation. In this capston project, the dataset will be used to predict the probability of accident based on the labelled data of different

# %%
import numpy as np
import pandas as pd

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
